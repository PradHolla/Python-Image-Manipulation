# %%
from PIL import Image
from psd_tools import PSDImage

# %%
psd = PSDImage.open('exple.psd')

# %%
psd.composite().save('example.jpg')

# %%
img = Image.open('example.jpg')
img = img.resize((1080, 1920))
img.save('example_resize.jpg')
